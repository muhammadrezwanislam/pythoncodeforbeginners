# %%
#Rock, Paper, Scissors Game
#Method one! 
player_one=input("enter your choice [Either Rock, Paper or Scissors]: ")
player_two=input("enter your choice [Either Rock, Paper or Scissors]: ")
a=["Rock","Paper","Scissors"]
if player_one==a[0] and player_two== a[1]:
    print("Congratulation! Player_two wins")
elif player_one==a[0] and player_two== a[2]:
    print("Congratulation! Player_one wins")
elif player_one==a[1] and player_two== a[0]:
    print("Congratulation! Player_one wins")
elif player_one==a[1] and player_two== a[2]:
    print("Congratulation! Player_two wins")
elif player_one==a[2] and player_two== a[0]:
    print("Congratulation! Player_two wins")
elif player_one==a[2] and player_two== a[1]:
    print("Congratulation! Player_one wins")
elif player_one==a[0] and player_two== a[0]:
    print("Match Drawn!")
elif player_one==a[1] and player_two== a[1]:
    print("Match Drawn!")
else:
    print("Match Drawn!")

new_message=input("Do you want to start a new game?[Yes or No]: ")
b=["Yes","No"]
if new_message==b[0]:
    my_function("Rock","Paper")
else:
    print("Thank you for playing the game!")

def my_function(player_one, player_two):
    player_one=input("enter your choice [Either Rock, Paper or Scissors]: ")
    player_two=input("enter your choice [Either Rock, Paper or Scissors]: ")
    a=["Rock","Paper","Scissors"]
    if player_one==a[0] and player_two== a[1]:
        print("Congratulation! Player_two wins")
    elif player_one==a[0] and player_two== a[2]:
        print("Congratulation! Player_one wins")
    elif player_one==a[1] and player_two== a[0]:
        print("Congratulation! Player_one wins")
    elif player_one==a[1] and player_two== a[2]:
        print("Congratulation! Player_two wins")
    elif player_one==a[2] and player_two== a[0]:
        print("Congratulation! Player_two wins")
    elif player_one==a[2] and player_two== a[1]:
        print("Congratulation! Player_one wins")
    elif player_one==a[0] and player_two== a[0]:
        print("Match Drawn!")
    elif player_one==a[1] and player_two== a[1]:
        print("Match Drawn!")
    else:
        print("Match Drawn!")
    new_message=input("Do you want to start a new game?[Yes or No]: ")
    b=["Yes","No"]
    if new_message==b[0]:
        my_function("Rock","Paper")
    else: 
        print("thank you!")

# %%
#method two
print(''' please pick one:
            rock
            paper
            scissors''')
while True:
    game_dict={'rock':1,'scissors':2,'paper':3}
    player_a=str(input("player a: "))
    player_b=str(input("player b: "))
    a=game_dict.get(player_a)
    b=game_dict.get(player_b)
    dif=a-b
    
    if dif in [-1,2]:
        print("player a wins!")
        if str(input("do you want to play another game, yes or no? \n"))=='yes':
            continue
        else:
            print("game over")
            break 
    elif dif in [-2,1]:
        print("player b wins!")
        if str(input("do you want to play another game, yes or no? \n"))=='yes':
            continue
        else:
            print("game over")
            break
    else: 
        print("match drawn, please continue")
        print('')
# Out:
#  please pick one:
#             rock
#             paper
#             scissors
# player a: rock
# player b: paper
# player b wins!
# do you want to play another game, yes or no?
# no
# game over
